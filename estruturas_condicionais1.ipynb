# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroGouvea13/PedroGouvea13/blob/main/estruturas_condicionais1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IF
if 5 < 10:
  print("Verdade")
# Out:
# Verdade

# %%
# IF/Else
num1 = 10
num2 = 10
if num1 > num2:
  print("Num1 é maior")
elif:
  print("Num2 é maior")
# Out:
# Num2 é maior

# %%
# IF/ELIF/ELSE

num1 = 100
num2 = 14
if num1 > num2:
  print("num1 e o maior. ")
elif num1 < num2:
  print("num2 e o maior.")
else:
  print("Os dois sao iguais.")
# Out:
# num1 e o maior.

# %%
num1 = 10
num2 = 5
num3 = 2
if (num1 > num2) and (num1 > num3):
  print('O num1 é o maio Numero.')
else:
  print("O num1 nao é o maior Numero.")
# Out:
# O num1 é o maio Numero.
